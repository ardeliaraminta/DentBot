# %%
import json
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import os


# Load intents data from JSON file
with open("new.json", 'r') as json_data:
    intents = json.load(json_data)

# Extract patterns and labels from intents data
X = []
y = []

for intent in intents['intents']:
    for pattern in intent['patterns']:
        X.append(pattern)
        y.append(intent['tag'])


tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
X_sequences = tokenizer.texts_to_sequences(X)
max_len = max(len(seq) for seq in X_sequences)
X_padded = pad_sequences(X_sequences, maxlen=max_len)


labels = list(set(y))
label_to_idx = {label: idx for idx, label in enumerate(labels)}
y_numeric = np.array([label_to_idx[label] for label in y])


X_train, X_val, y_train, y_val = train_test_split(X_padded, y_numeric, test_size=0.2, random_state=42)

vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 100


model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))
model.add(Bidirectional(LSTM(96, dropout=0.5, recurrent_dropout=0.2, kernel_regularizer='l2')))
model.add(Dense(96, activation='relu', kernel_regularizer='l2'))
model.add(Dropout(0.5))
model.add(Dense(len(labels), activation='softmax'))


model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=40, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

y_val_probs = model.predict(X_val)
y_val_pred_labels = [labels[np.argmax(prob)] for prob in y_val_probs]
y_val_true_labels = [labels[idx] for idx in y_val]

report = classification_report(y_val_true_labels, y_val_pred_labels)
print("Classification Report:")
print(report)
# Out:
# Epoch 1/40
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.0753 - loss: 6.4294 - val_accuracy: 0.0721 - val_loss: 4.7773
# Epoch 2/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1264 - loss: 4.4180 - val_accuracy: 0.0721 - val_loss: 3.5984
# Epoch 3/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1390 - loss: 3.4468 - val_accuracy: 0.0721 - val_loss: 3.0575
# Epoch 4/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1472 - loss: 2.9824 - val_accuracy: 0.2523 - val_loss: 2.7825
# Epoch 5/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1902 - loss: 2.7438 - val_accuracy: 0.2432 - val_loss: 2.6333
# Epoch 6/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2068 - loss: 2.5423 - val_accuracy: 0.2523 - val_loss: 2.2303
# Epoch 7/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2797 - loss: 2.2559 - val_accuracy: 0.2883 - val_loss: 1.9912
# Epoch 8/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2766 - loss: 2.0699 - val_accuracy: 0.3153 - val_loss: 1.8724
# Epoch 9/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3393 - loss: 1.9619 - val_accuracy: 0.3153 - val_loss: 1.7305
# Epoch 10/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3516 - loss: 1.9141 - val_accuracy: 0.4234 - val_loss: 1.6123
# Epoch 11/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4402 - loss: 1.7786 - val_accuracy: 0.5045 - val_loss: 1.5427
# Epoch 12/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4830 - loss: 1.6203 - val_accuracy: 0.5315 - val_loss: 1.4087
# Epoch 13/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5350 - loss: 1.5233 - val_accuracy: 0.5856 - val_loss: 1.3439
# Epoch 14/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5645 - loss: 1.4959 - val_accuracy: 0.6306 - val_loss: 1.2634
# Epoch 15/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5775 - loss: 1.3727 - val_accuracy: 0.7117 - val_loss: 1.1916
# Epoch 16/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6209 - loss: 1.3437 - val_accuracy: 0.6847 - val_loss: 1.1059
# Epoch 17/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6285 - loss: 1.2719 - val_accuracy: 0.7027 - val_loss: 1.1050
# Epoch 18/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6659 - loss: 1.1996 - val_accuracy: 0.7207 - val_loss: 0.9920
# Epoch 19/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6550 - loss: 1.1629 - val_accuracy: 0.7568 - val_loss: 0.9909
# Epoch 20/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7013 - loss: 1.0933 - val_accuracy: 0.7928 - val_loss: 0.9136
# Epoch 21/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7728 - loss: 0.9887 - val_accuracy: 0.7748 - val_loss: 0.9183
# Epoch 22/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7802 - loss: 1.0089 - val_accuracy: 0.8108 - val_loss: 0.8727
# Epoch 23/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7678 - loss: 0.9565 - val_accuracy: 0.7928 - val_loss: 0.8562
# Epoch 24/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7481 - loss: 0.9263 - val_accuracy: 0.8468 - val_loss: 0.8264
# Epoch 25/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8106 - loss: 0.9237 - val_accuracy: 0.8108 - val_loss: 0.8059
# Epoch 26/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8274 - loss: 0.8460 - val_accuracy: 0.8468 - val_loss: 0.8702
# Epoch 27/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8054 - loss: 0.9546 - val_accuracy: 0.8649 - val_loss: 0.7952
# Epoch 28/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8268 - loss: 0.8947 - val_accuracy: 0.8468 - val_loss: 0.7391
# Epoch 29/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8508 - loss: 0.7688 - val_accuracy: 0.8829 - val_loss: 0.7536
# Epoch 30/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8482 - loss: 0.7677 - val_accuracy: 0.8468 - val_loss: 0.7231
# Epoch 31/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8845 - loss: 0.7362 - val_accuracy: 0.8829 - val_loss: 0.6913
# Epoch 32/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8655 - loss: 0.7114 - val_accuracy: 0.8378 - val_loss: 0.6909
# Epoch 33/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8877 - loss: 0.6997 - val_accuracy: 0.8919 - val_loss: 0.6956
# Epoch 34/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8926 - loss: 0.6854 - val_accuracy: 0.8649 - val_loss: 0.6730
# Epoch 35/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8808 - loss: 0.7180 - val_accuracy: 0.8919 - val_loss: 0.6187
# Epoch 36/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9077 - loss: 0.6570 - val_accuracy: 0.8739 - val_loss: 0.6296
# Epoch 37/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8717 - loss: 0.6780 - val_accuracy: 0.8919 - val_loss: 0.6502
# Epoch 38/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9177 - loss: 0.6304 - val_accuracy: 0.8739 - val_loss: 0.6377
# Epoch 39/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8986 - loss: 0.6130 - val_accuracy: 0.8739 - val_loss: 0.6248
# Epoch 40/40
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9099 - loss: 0.6060 - val_accuracy: 0.8919 - val_loss: 0.6019
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step
# Classification Report:
#                                         precision    recall  f1-score   support
#
#                About_CBCT_Review_Scans       1.00      1.00      1.00         2
#            About_IOD_Protocol_Approval       1.00      0.89      0.94         9
# About_STI_Protocol_Implant_Restoration       0.83      1.00      0.91         5
#                                General       1.00      1.00      1.00         7
#           IOD_Appointment_Consultation       1.00      0.70      0.82        10
#                              IOD_Tools       0.75      0.75      0.75         4
#                      IOD_Treatment_Fee       0.73      1.00      0.84         8
#                 IOD_Treatment_Implants       0.80      1.00      0.89         8
#        Message_Schedule_Assign_Patient       1.00      0.40      0.57         5
#                  STI_Crown_Appointment       1.00      0.91      0.95        11
#  STI_Orthodontic_Protocol_Consultation       1.00      1.00      1.00        12
#       STI_Protocol_Implant_Consulation       0.83      1.00      0.91         5
#                              STI_Tools       0.95      1.00      0.98        20
#                      STI_Treatment_Fee       0.40      0.40      0.40         5
#
#                               accuracy                           0.89       111
#                              macro avg       0.88      0.86      0.85       111
#                           weighted avg       0.91      0.89      0.89       111
